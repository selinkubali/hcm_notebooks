# %%
import pandas as pd
import numpy as np
from firthlogist import FirthLogisticRegression
from statsmodels.stats.multitest import multipletests
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
genes = ["ACTN2", "ALPK3", "DES", "FLNC", "MYBPC3", "MYH6", "MYH7", "PTPN11", "TNNI3", "TTR"]

deleterious_vals = {}
deleterious_odds = {}
missense_vals = {}
missense_odds = {} 
def logistic_regression(gene):


    # read in file
    file_name=gene+'.csv'
    phenotypic_data = pd.read_csv("/Users/uriel/Downloads/work_temp/gnomadAI_lifelines/"+file_name, dtype={
            'is_family_hist':'boolean',
            'is_hcm':'boolean'
            })
    
    
    
    phenotypic_data = phenotypic_data.drop(["Name", "index"], axis = 1)
    phenotypic_data = phenotypic_data.dropna()

    #percentiles = np.percentile(phenotypic_data[phenotypic_data['missense_variant'] == 1]['am_pathogenicity'], 75)
    #phenotypic_data['missense_variant'] = np.where((phenotypic_data['am_pathogenicity'] >= percentiles) & (phenotypic_data['missense_variant'] == 1), 1, 0)


    print("Missense, is hcm:", phenotypic_data[phenotypic_data["missense_variant"] == 1].sum()['is_hcm'])
    print("Missense, all:", phenotypic_data[phenotypic_data["missense_variant"] == 1].sum()['missense_variant'])
    print("Deleterious, is hcm:", phenotypic_data[phenotypic_data["deleterious"] == 1].sum()['is_hcm'])
    print("Deleterious, all:", phenotypic_data[phenotypic_data["deleterious"] == 1].sum()['deleterious'])


  

    X=phenotypic_data[['sex','is_family_hist', 'age', 'principal_component_1', 'principal_component_4', 'prs_score', 'deleterious', 'missense_variant', 'synonymous_variant']].values
    y = phenotypic_data['is_hcm'].values
    feature_names = ['sex','is_family_hist', 'age', 'principal_component_1', 'principal_component_4', 'prs_score', 'deleterious', 'missense_variant', 'synonymous_variant']
    fl = FirthLogisticRegression()
    fl.fit(X, y)
    fl.summary(xname = feature_names)

    deleterious_vals.update({gene:fl.pvals_[6]})
    deleterious_odds.update({gene:np.exp(fl.coef_[6])})
    missense_vals.update({gene:fl.pvals_[7]})
    missense_odds.update({gene:np.exp(fl.coef_[7])})
    plt.hist(phenotypic_data[phenotypic_data['missense_variant'] == 1]['am_pathogenicity'], bins=30, color='skyblue', edgecolor='black')
    plt.xticks([0, 0.25, 0.5, 0.75, 1])
    plt.xlabel("AlphaMissense score")
    plt.ylabel("Count")



for gene in genes:
    print(gene)
    logistic_regression(gene)
    plt.show()
# Out:
# ACTN2
# Missense, is hcm: 10.0
# Missense, all: 5068.0
# Deleterious, is hcm: 1.0
# Deleterious, all: 495.0
#                               coef      std err        [0.025       0.975]       p-value
# ---------------------  -----------  -----------  ------------  -----------  ------------
# sex                     0.774942    0.0773729      0.623869     0.928134    1.45401e-24
# is_family_hist          0.586402    0.0762601      0.437067     0.736923    1.00886e-14
# age                     0.030665    0.00493786     0.0210143    0.0404362   2.94862e-10
# principal_component_1   0.00354569  0.000454995    0.00260931   0.00440249  4.7357e-11
# principal_component_4  -0.0086104   0.00252989    -0.0133475   -0.00337045  0.00179469
# prs_score              34.9862      2.6106        29.8412      40.1075      1.59811e-39
# deleterious             0.689134    0.819357      -1.47994      1.96433     0.448874
# ...

# %% [markdown]
# ### Deleterious variants

# %%
print("Deleterious odds: ", deleterious_odds)
p_adjusted = multipletests(list(deleterious_vals.values()), alpha=0.05, method='bonferroni')
updated_dict = {key: new_p_val for key, new_p_val in zip(deleterious_vals.keys(), p_adjusted[1])}
print("Deleterious p-values: ", updated_dict)
p_val_true_dict = {key: new_p_val for key, new_p_val in zip(deleterious_vals.keys(), p_adjusted[0])}
print("Deleterious p-values < 0.05?: ",p_val_true_dict)
# Out:
# Deleterious odds:  {'ACTN2': 1.9864229041905361, 'ALPK3': 6.383189950373389, 'DES': 0.9510457315008317, 'FLNC': 1.4535956590536805, 'MYBPC3': 56.35039458783428, 'MYH6': 0.6682816393740486, 'MYH7': 1.6713454920064734, 'PTPN11': 6.136985166313755, 'TNNI3': 18.877546947480205, 'TTR': 2.7909968902391595}
# Deleterious p-values:  {'ACTN2': 1.0, 'ALPK3': 0.00037059871793237406, 'DES': 1.0, 'FLNC': 1.0, 'MYBPC3': 7.249737892415848e-43, 'MYH6': 1.0, 'MYH7': 1.0, 'PTPN11': 0.27684236711810717, 'TNNI3': 0.15289934551209106, 'TTR': 1.0}
# Deleterious p-values < 0.05?:  {'ACTN2': False, 'ALPK3': True, 'DES': False, 'FLNC': False, 'MYBPC3': True, 'MYH6': False, 'MYH7': False, 'PTPN11': False, 'TNNI3': False, 'TTR': False}

# %% [markdown]
# ### Missense variants

# %%
print("Missense odds: ", missense_odds)
p_adjusted = multipletests(list(missense_vals.values()), alpha=0.05, method='bonferroni')
updated_dict = {key: new_p_val for key, new_p_val in zip(missense_vals.keys(), p_adjusted[1])}
print("Missense p-values: ", updated_dict)
p_val_true_dict = {key: new_p_val for key, new_p_val in zip(missense_vals.keys(), p_adjusted[0])}
print("Missense p-values < 0.05?: ",p_val_true_dict)
# Out:
# Missense odds:  {'ACTN2': 1.2111536015327269, 'ALPK3': 2.61759574916028, 'DES': 0.5308809159201997, 'FLNC': 2.4716006420757584, 'MYBPC3': 1.9791003433216272, 'MYH6': 0.48927767775264164, 'MYH7': 9.216825707810633, 'PTPN11': 2.818877754327659, 'TNNI3': 16.135405436744346, 'TTR': 4.817979067157136}
# dict_values([0.7692486256622327, 0.010973537335406963, 0.6169435391655906, 0.01592844811886094, 0.15223283342750846, 0.3216844071794913, 6.843790566693909e-10, 0.2797595277086268, 0.0025922858132892625, 0.1273608976343769])
# Missense p-values:  {'ACTN2': 1.0, 'ALPK3': 0.10973537335406963, 'DES': 1.0, 'FLNC': 0.15928448118860938, 'MYBPC3': 1.0, 'MYH6': 1.0, 'MYH7': 6.843790566693909e-09, 'PTPN11': 1.0, 'TNNI3': 0.025922858132892624, 'TTR': 1.0}
# Missense p-values < 0.05?:  {'ACTN2': False, 'ALPK3': False, 'DES': False, 'FLNC': False, 'MYBPC3': False, 'MYH6': False, 'MYH7': True, 'PTPN11': False, 'TNNI3': True, 'TTR': False}
